# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # EX2
# #### t-SNE: The effect of various perplexity values on the shape
# ###### https://scikit-learn.org/stable/auto_examples/manifold/plot_t_sne_perplexity.html#sphx-glr-auto-examples-manifold-plot-t-sne-perplexity-py

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter
from sklearn import manifold, datasets
from time import time

n_samples = 150
n_components = 2
(fig, subplots) = plt.subplots(3, 5, figsize=(15, 8))
perplexities = [5, 30, 50, 100]

X, y = datasets.make_circles(
    n_samples=n_samples, factor=0.5, noise=0.05, random_state=0
)

red = y == 0
green = y == 1

ax = subplots[0][0]
ax.scatter(X[red, 0], X[red, 1], c="r")
ax.scatter(X[green, 0], X[green, 1], c="g")
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis("tight")

for i, perplexity in enumerate(perplexities):
    ax = subplots[0][i + 1]

    t0 = time()
    tsne = manifold.TSNE(
        n_components=n_components,
        init="random",
        random_state=0,
        perplexity=perplexity,
        n_iter=300,
    )
    Y = tsne.fit_transform(X)
    t1 = time()
    print("circles, perplexity=%d in %.2g sec" % (perplexity, t1 - t0))
    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[red, 0], Y[red, 1], c="r")
    ax.scatter(Y[green, 0], Y[green, 1], c="g")
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis("tight")

# Another example using s-curve
X, color = datasets.make_s_curve(n_samples, random_state=0)

ax = subplots[1][0]
ax.scatter(X[:, 0], X[:, 2], c=color)
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())

for i, perplexity in enumerate(perplexities):
    ax = subplots[1][i + 1]

    t0 = time()
    tsne = manifold.TSNE(
        n_components=n_components,
        init="random",
        random_state=0,
        perplexity=perplexity,
        learning_rate="auto",
        n_iter=300,
    )
    Y = tsne.fit_transform(X)
    t1 = time()
    print("S-curve, perplexity=%d in %.2g sec" % (perplexity, t1 - t0))

    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=color)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis("tight")


# Another example using a 2D uniform grid
x = np.linspace(0, 1, int(np.sqrt(n_samples)))
xx, yy = np.meshgrid(x, x)
X = np.hstack(
    [
        xx.ravel().reshape(-1, 1),
        yy.ravel().reshape(-1, 1),
    ]
)
color = xx.ravel()
ax = subplots[2][0]
ax.scatter(X[:, 0], X[:, 1], c=color)
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())

for i, perplexity in enumerate(perplexities):
    ax = subplots[2][i + 1]

    t0 = time()
    tsne = manifold.TSNE(
        n_components=n_components,
        init="random",
        random_state=0,
        perplexity=perplexity,
        n_iter=400,
    )
    Y = tsne.fit_transform(X)
    t1 = time()
    print("uniform grid, perplexity=%d in %.2g sec" % (perplexity, t1 - t0))

    ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=color)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis("tight")


plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# circles, perplexity=5 in 0.37 sec
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# circles, perplexity=30 in 0.45 sec
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# circles, perplexity=50 in 0.28 sec
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# circles, perplexity=100 in 0.36 sec
# S-curve, perplexity=5 in 0.26 sec
# S-curve, perplexity=30 in 0.31 sec
# S-curve, perplexity=50 in 0.27 sec
# S-curve, perplexity=100 in 0.27 sec
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# uniform grid, perplexity=5 in 0.27 sec
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# uniform grid, perplexity=30 in 0.68 sec
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# uniform grid, perplexity=50 in 2.2 sec
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# uniform grid, perplexity=100 in 0.47 sec

# %% [markdown]
# ### Comment:
#
# ##### A second feature of t-SNE is a tuneable parameter, “perplexity,” which says (loosely) how to balance attention between local and global aspects of your data. The parameter is, in a sense, a guess about the number of close neighbors each point has.
#
# The larger the perplexity, the more non-local information will be retained in the dimensionality reduction result.
#
# So if your perplexity is very small, then there will be fewer pairs that feel any attraction and the resulting embedding will tend to be "fluffy": repulsive forces will dominate and will inflate the whole embedding to a bubble-like round shape.
#
# On the other hand, if your perplexity is large, clusters will tend to shrink into denser structures.

# %% [markdown]
# # Ex3:
# #### Dùng word embedding (https://habr.com/en/company/vk/blog/449984/), chọn ra 10 từ bất kì, với mỗi từ tìm 10 từ có embedding gần nhất
# ##### a. nhận xét về ngữ nghĩa các từ có embedding gần nhau
# ##### b. dùng t-SNE giảm chiều các vector embedding về 2 chiều, nhận xét các cụm

# %%
# import gensim

# model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNewsvectorsnegative300.bin', binary=True, encoding='utf8')

# I have tried in so many ways to run this code (or equally), but maybe have problem with the data, which i can execute this ordered code from the very beginning
# then can not afterwards

# %%
import re
import codecs


def preprocess_text(text):
    text = re.sub('[^a-zA-Zа-яА-Я1-9]+', ' ', text)
    text = re.sub(' +', ' ', text)
    return text.strip()


def prepare_for_w2v(filename_from, filename_to, lang):
    raw_text = codecs.open(filename_from, "r", encoding='windows-1251').read()
    with open(filename_to, 'w', encoding='utf-8') as f:
        for sentence in nltk.sent_tokenize(raw_text, lang):
            print(preprocess_text(sentence.lower()), file=f)

# %%
import multiprocessing
from gensim.models import Word2Vec


def train_word2vec(filename):
    data = gensim.models.word2vec.LineSentence(filename)
    return Word2Vec(data, size=200, window=5, min_count=5, workers=multiprocessing.cpu_count())

# %%
# keys = ['Paris', 'Python', 'Sunday', 'Tolstoy', 'Twitter', 'bachelor', 'delivery', 'election', 'expensive',
#         'experience', 'financial', 'food', 'iOS', 'peace', 'release', 'war']

# embedding_clusters = []
# word_clusters = []
# for word in keys:
#     embeddings = []
#     words = []
#     for similar_word, _ in model.most_similar(word, topn=30):
#         words.append(similar_word)
#         embeddings.append(model[similar_word])
#     embedding_clusters.append(embeddings)
#     word_clusters.append(words)

# %% [markdown]
# # EX5:
# #### Đọc paper https://www.jmlr.org/papers/volume9/vandermaaten08a/vandermaaten08a.pdf

# %% [markdown]
# # EX6:
# #### Implement t-SNE, variance can be fixed or found out from perplexity

# %%
import numpy as np
from sklearn.datasets import load_digits
from scipy.spatial.distance import pdist
from sklearn.manifold._t_sne import _joint_probabilities
from scipy import linalg
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import squareform
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
palette = sns.color_palette("bright", 10)

# %%
X, y = load_digits(return_X_y=True)

# %%
MACHINE_EPSILON = np.finfo(np.double).eps
n_components = 2
perplexity = 30

# %%
def _kl_divergence(params, P, degrees_of_freedom, n_samples, n_components):
    X_embedded = params.reshape(n_samples, n_components)
    
    dist = pdist(X_embedded, "sqeuclidean")
    dist /= degrees_of_freedom
    dist += 1.
    dist **= (degrees_of_freedom + 1.0) / -2.0
    Q = np.maximum(dist / (2.0 * np.sum(dist)), MACHINE_EPSILON)
    
    # Kullback-Leibler divergence of P and Q
    kl_divergence = 2.0 * np.dot(P, np.log(np.maximum(P, MACHINE_EPSILON) / Q))
    
    # Gradient: dC/dY
    grad = np.ndarray((n_samples, n_components), dtype=params.dtype)
    PQd = squareform((P - Q) * dist)
    for i in range(n_samples):
        grad[i] = np.dot(np.ravel(PQd[i], order='K'),
                         X_embedded[i] - X_embedded)
    grad = grad.ravel()
    c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
    grad *= c
    return kl_divergence, grad

# %%
def _gradient_descent(obj_func, p0, args, it=0, n_iter=1000,
                      n_iter_check=1, n_iter_without_progress=300,
                      momentum=0.8, learning_rate=200.0, min_gain=0.01,
                      min_grad_norm=1e-7):
    
    p = p0.copy().ravel()
    update = np.zeros_like(p)
    gains = np.ones_like(p)
    error = np.finfo(np.float).max
    best_error = np.finfo(np.float).max
    best_iter = i = it
    
    for i in range(it, n_iter):
        error, grad = obj_func(p, *args)
        grad_norm = linalg.norm(grad)
        inc = update * grad < 0.0
        dec = np.invert(inc)
        gains[inc] += 0.2
        gains[dec] *= 0.8
        np.clip(gains, min_gain, np.inf, out=gains)
        grad *= gains
        update = momentum * update - learning_rate * grad
        p += update
        print("[t-SNE] Iteration %d: error = %.7f,"
                      " gradient norm = %.7f"
                      % (i + 1, error, grad_norm))
        
        if error < best_error:
                best_error = error
                best_iter = i
        elif i - best_iter > n_iter_without_progress:
            break
        
        if grad_norm <= min_grad_norm:
            break
    return p

# %%
def _tsne(P, degrees_of_freedom, n_samples, X_embedded):
    params = X_embedded.ravel()
    
    obj_func = _kl_divergence
    
    params = _gradient_descent(obj_func, params, [P, degrees_of_freedom, n_samples, n_components])
        
    X_embedded = params.reshape(n_samples, n_components)
    return X_embedded

# %%
def fit(X):
    n_samples = X.shape[0]
    
    # Compute euclidean distance
    distances = pairwise_distances(X, metric='euclidean', squared=True)
    
    # Compute joint probabilities p_ij from distances.
    P = _joint_probabilities(distances=distances, desired_perplexity=perplexity, verbose=False)
    
    # The embedding is initialized with iid samples from Gaussians with standard deviation 1e-4.
    X_embedded = 1e-4 * np.random.mtrand._rand.randn(n_samples, n_components).astype(np.float32)
    
    # degrees_of_freedom = n_components - 1 comes from
    # "Learning a Parametric Embedding by Preserving Local Structure"
    # Laurens van der Maaten, 2009.
    degrees_of_freedom = max(n_components - 1, 1)
    
    return _tsne(P, degrees_of_freedom, n_samples, X_embedded=X_embedded)

# %%
X_embedded = fit(X)
# Out:
# /var/folders/b0/n1lz5zk51z374mpb3hyxn5n00000gp/T/ipykernel_6009/790759570.py:9: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   error = np.finfo(np.float).max
# /var/folders/b0/n1lz5zk51z374mpb3hyxn5n00000gp/T/ipykernel_6009/790759570.py:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   best_error = np.finfo(np.float).max
# [t-SNE] Iteration 1: error = 3.9810953, gradient norm = 0.0000047
# [t-SNE] Iteration 2: error = 3.9810953, gradient norm = 0.0000048
# [t-SNE] Iteration 3: error = 3.9810953, gradient norm = 0.0000059
# [t-SNE] Iteration 4: error = 3.9810953, gradient norm = 0.0000091
# [t-SNE] Iteration 5: error = 3.9810952, gradient norm = 0.0000156
# [t-SNE] Iteration 6: error = 3.9810950, gradient norm = 0.0000287
# [t-SNE] Iteration 7: error = 3.9810943, gradient norm = 0.0000562
# [t-SNE] Iteration 8: error = 3.9810914, gradient norm = 0.0001165
# [t-SNE] Iteration 9: error = 3.9810772, gradient norm = 0.0002547
# [t-SNE] Iteration 10: error = 3.9810026, gradient norm = 0.0005844
# [t-SNE] Iteration 11: error = 3.9805733, gradient norm = 0.0014003
# [t-SNE] Iteration 12: error = 3.9779066, gradient norm = 0.0034590
# [t-SNE] Iteration 13: error = 3.9608857, gradient norm = 0.0083054
# [t-SNE] Iteration 14: error = 3.8694743, gradient norm = 0.0158242
# [t-SNE] Iteration 15: error = 3.5951306, gradient norm = 0.0185068
# [t-SNE] Iteration 16: error = 3.2169967, gradient norm = 0.0151963
# [t-SNE] Iteration 17: error = 2.8840455, gradient norm = 0.0118801
# [t-SNE] Iteration 18: error = 2.6212549, gradient norm = 0.0097227
# [t-SNE] Iteration 19: error = 2.4123606, gradient norm = 0.0084142
# [t-SNE] Iteration 20: error = 2.2415208, gradient norm = 0.0074690
# [t-SNE] Iteration 21: error = 2.0995608, gradient norm = 0.0068820
# [t-SNE] Iteration 22: error = 1.9771717, gradient norm = 0.0065742
# [t-SNE] Iteration 23: error = 1.8723457, gradient norm = 0.0058524
# [t-SNE] Iteration 24: error = 1.7873610, gradient norm = 0.0054836
# [t-SNE] Iteration 25: error = 1.7166577, gradient norm = 0.0052044
# [t-SNE] Iteration 26: error = 1.6564529, gradient norm = 0.0048521
# [t-SNE] Iteration 27: error = 1.6050561, gradient norm = 0.0045341
# [t-SNE] Iteration 28: error = 1.5613214, gradient norm = 0.0042654
# [t-SNE] Iteration 29: error = 1.5239548, gradient norm = 0.0041037
# [t-SNE] Iteration 30: error = 1.4912029, gradient norm = 0.0039599
# [t-SNE] Iteration 31: error = 1.4619447, gradient norm = 0.0038010
# [t-SNE] Iteration 32: error = 1.4354806, gradient norm = 0.0035917
# [t-SNE] Iteration 33: error = 1.4116439, gradient norm = 0.0033448
# [t-SNE] Iteration 34: error = 1.3902939, gradient norm = 0.0031408
# [t-SNE] Iteration 35: error = 1.3709389, gradient norm = 0.0030050
# [t-SNE] Iteration 36: error = 1.3530211, gradient norm = 0.0028809
# [t-SNE] Iteration 37: error = 1.3362409, gradient norm = 0.0027162
# [t-SNE] Iteration 38: error = 1.3206459, gradient norm = 0.0025524
# [t-SNE] Iteration 39: error = 1.3063182, gradient norm = 0.0024730
# [t-SNE] Iteration 40: error = 1.2930339, gradient norm = 0.0024366
# [t-SNE] Iteration 41: error = 1.2804587, gradient norm = 0.0023806
# [t-SNE] Iteration 42: error = 1.2683505, gradient norm = 0.0022747
# [t-SNE] Iteration 43: error = 1.2567175, gradient norm = 0.0021454
# [t-SNE] Iteration 44: error = 1.2456104, gradient norm = 0.0020252
# [t-SNE] Iteration 45: error = 1.2350412, gradient norm = 0.0019405
# [t-SNE] Iteration 46: error = 1.2249333, gradient norm = 0.0018758
# [t-SNE] Iteration 47: error = 1.2152544, gradient norm = 0.0017946
# [t-SNE] Iteration 48: error = 1.2061168, gradient norm = 0.0017848
# [t-SNE] Iteration 49: error = 1.1972096, gradient norm = 0.0017263
# [t-SNE] Iteration 50: error = 1.1884247, gradient norm = 0.0016328
# [t-SNE] Iteration 51: error = 1.1798083, gradient norm = 0.0015565
# [t-SNE] Iteration 52: error = 1.1713533, gradient norm = 0.0015249
# [t-SNE] Iteration 53: error = 1.1630242, gradient norm = 0.0015077
# [t-SNE] Iteration 54: error = 1.1547930, gradient norm = 0.0014644
# [t-SNE] Iteration 55: error = 1.1467128, gradient norm = 0.0013982
# [t-SNE] Iteration 56: error = 1.1389509, gradient norm = 0.0013542
# [t-SNE] Iteration 57: error = 1.1315081, gradient norm = 0.0013509
# [t-SNE] Iteration 58: error = 1.1242602, gradient norm = 0.0013321
# [t-SNE] Iteration 59: error = 1.1172087, gradient norm = 0.0013067
# [t-SNE] Iteration 60: error = 1.1103751, gradient norm = 0.0012693
# [t-SNE] Iteration 61: error = 1.1038440, gradient norm = 0.0012271
# [t-SNE] Iteration 62: error = 1.0977431, gradient norm = 0.0012352
# [t-SNE] Iteration 63: error = 1.0919769, gradient norm = 0.0012866
# [t-SNE] Iteration 64: error = 1.0862883, gradient norm = 0.0013220
# [t-SNE] Iteration 65: error = 1.0805409, gradient norm = 0.0012954
# [t-SNE] Iteration 66: error = 1.0747935, gradient norm = 0.0012273
# [t-SNE] Iteration 67: error = 1.0691700, gradient norm = 0.0011311
# [t-SNE] Iteration 68: error = 1.0639134, gradient norm = 0.0010454
# [t-SNE] Iteration 69: error = 1.0590716, gradient norm = 0.0010523
# [t-SNE] Iteration 70: error = 1.0543245, gradient norm = 0.0010574
# [t-SNE] Iteration 71: error = 1.0495621, gradient norm = 0.0010329
# [t-SNE] Iteration 72: error = 1.0448543, gradient norm = 0.0009880
# [t-SNE] Iteration 73: error = 1.0402898, gradient norm = 0.0009541
# [t-SNE] Iteration 74: error = 1.0359338, gradient norm = 0.0009312
# [t-SNE] Iteration 75: error = 1.0317746, gradient norm = 0.0009427
# [t-SNE] Iteration 76: error = 1.0276508, gradient norm = 0.0009051
# [t-SNE] Iteration 77: error = 1.0236187, gradient norm = 0.0008672
# [t-SNE] Iteration 78: error = 1.0196970, gradient norm = 0.0008590
# [t-SNE] Iteration 79: error = 1.0158007, gradient norm = 0.0008576
# [t-SNE] Iteration 80: error = 1.0118927, gradient norm = 0.0008468
# [t-SNE] Iteration 81: error = 1.0080616, gradient norm = 0.0008122
# [t-SNE] Iteration 82: error = 1.0043845, gradient norm = 0.0007863
# [t-SNE] Iteration 83: error = 1.0008312, gradient norm = 0.0007826
# [t-SNE] Iteration 84: error = 0.9973416, gradient norm = 0.0007948
# [t-SNE] Iteration 85: error = 0.9938335, gradient norm = 0.0007779
# [t-SNE] Iteration 86: error = 0.9903060, gradient norm = 0.0007186
# [t-SNE] Iteration 87: error = 0.9868380, gradient norm = 0.0006612
# [t-SNE] Iteration 88: error = 0.9834692, gradient norm = 0.0006799
# [t-SNE] Iteration 89: error = 0.9801202, gradient norm = 0.0007021
# [t-SNE] Iteration 90: error = 0.9767464, gradient norm = 0.0007085
# [t-SNE] Iteration 91: error = 0.9733414, gradient norm = 0.0007021
# [t-SNE] Iteration 92: error = 0.9699070, gradient norm = 0.0007029
# [t-SNE] Iteration 93: error = 0.9664154, gradient norm = 0.0007337
# [t-SNE] Iteration 94: error = 0.9627873, gradient norm = 0.0008005
# [t-SNE] Iteration 95: error = 0.9588939, gradient norm = 0.0008663
# [t-SNE] Iteration 96: error = 0.9549043, gradient norm = 0.0008796
# [t-SNE] Iteration 97: error = 0.9510751, gradient norm = 0.0008145
# [t-SNE] Iteration 98: error = 0.9475919, gradient norm = 0.0007320
# [t-SNE] Iteration 99: error = 0.9446201, gradient norm = 0.0007686
# [t-SNE] Iteration 100: error = 0.9418569, gradient norm = 0.0008102
# [t-SNE] Iteration 101: error = 0.9390414, gradient norm = 0.0007683
# [t-SNE] Iteration 102: error = 0.9362134, gradient norm = 0.0007111
# [t-SNE] Iteration 103: error = 0.9334208, gradient norm = 0.0006831
# [t-SNE] Iteration 104: error = 0.9306559, gradient norm = 0.0006690
# [t-SNE] Iteration 105: error = 0.9279388, gradient norm = 0.0006476
# [t-SNE] Iteration 106: error = 0.9253001, gradient norm = 0.0006339
# [t-SNE] Iteration 107: error = 0.9227019, gradient norm = 0.0006032
# [t-SNE] Iteration 108: error = 0.9201594, gradient norm = 0.0005864
# [t-SNE] Iteration 109: error = 0.9176796, gradient norm = 0.0005795
# [t-SNE] Iteration 110: error = 0.9152459, gradient norm = 0.0005713
# [t-SNE] Iteration 111: error = 0.9128458, gradient norm = 0.0005521
# [t-SNE] Iteration 112: error = 0.9104773, gradient norm = 0.0005210
# [t-SNE] Iteration 113: error = 0.9081634, gradient norm = 0.0004922
# [t-SNE] Iteration 114: error = 0.9059451, gradient norm = 0.0004888
# [t-SNE] Iteration 115: error = 0.9037954, gradient norm = 0.0004825
# [t-SNE] Iteration 116: error = 0.9017308, gradient norm = 0.0004860
# [t-SNE] Iteration 117: error = 0.8997230, gradient norm = 0.0004964
# [t-SNE] Iteration 118: error = 0.8977294, gradient norm = 0.0004856
# [t-SNE] Iteration 119: error = 0.8957670, gradient norm = 0.0004745
# [t-SNE] Iteration 120: error = 0.8938283, gradient norm = 0.0004599
# [t-SNE] Iteration 121: error = 0.8919014, gradient norm = 0.0004502
# [t-SNE] Iteration 122: error = 0.8899778, gradient norm = 0.0004456
# [t-SNE] Iteration 123: error = 0.8880522, gradient norm = 0.0004451
# [t-SNE] Iteration 124: error = 0.8861144, gradient norm = 0.0004459
# [t-SNE] Iteration 125: error = 0.8841984, gradient norm = 0.0004191
# [t-SNE] Iteration 126: error = 0.8824530, gradient norm = 0.0004528
# [t-SNE] Iteration 127: error = 0.8807635, gradient norm = 0.0004982
# [t-SNE] Iteration 128: error = 0.8790234, gradient norm = 0.0004666
# [t-SNE] Iteration 129: error = 0.8773053, gradient norm = 0.0004223
# [t-SNE] Iteration 130: error = 0.8756421, gradient norm = 0.0004178
# [t-SNE] Iteration 131: error = 0.8739977, gradient norm = 0.0004087
# [t-SNE] Iteration 132: error = 0.8723788, gradient norm = 0.0003936
# [t-SNE] Iteration 133: error = 0.8708011, gradient norm = 0.0003850
# [t-SNE] Iteration 134: error = 0.8692534, gradient norm = 0.0003687
# [t-SNE] Iteration 135: error = 0.8677372, gradient norm = 0.0003565
# [t-SNE] Iteration 136: error = 0.8662557, gradient norm = 0.0003493
# [t-SNE] Iteration 137: error = 0.8648068, gradient norm = 0.0003469
# [t-SNE] Iteration 138: error = 0.8633885, gradient norm = 0.0003476
# [t-SNE] Iteration 139: error = 0.8619949, gradient norm = 0.0003471
# [t-SNE] Iteration 140: error = 0.8606215, gradient norm = 0.0003432
# [t-SNE] Iteration 141: error = 0.8592668, gradient norm = 0.0003369
# [t-SNE] Iteration 142: error = 0.8579322, gradient norm = 0.0003350
# [t-SNE] Iteration 143: error = 0.8566157, gradient norm = 0.0003356
# [t-SNE] Iteration 144: error = 0.8553127, gradient norm = 0.0003315
# [t-SNE] Iteration 145: error = 0.8540239, gradient norm = 0.0003181
# [t-SNE] Iteration 146: error = 0.8527591, gradient norm = 0.0003169
# [t-SNE] Iteration 147: error = 0.8515144, gradient norm = 0.0003152
# [t-SNE] Iteration 148: error = 0.8502862, gradient norm = 0.0003075
# [t-SNE] Iteration 149: error = 0.8490783, gradient norm = 0.0003119
# [t-SNE] Iteration 150: error = 0.8478843, gradient norm = 0.0003103
# [t-SNE] Iteration 151: error = 0.8467060, gradient norm = 0.0003083
# [t-SNE] Iteration 152: error = 0.8455436, gradient norm = 0.0003039
# [t-SNE] Iteration 153: error = 0.8443994, gradient norm = 0.0002999
# [t-SNE] Iteration 154: error = 0.8432705, gradient norm = 0.0002942
# [t-SNE] Iteration 155: error = 0.8421576, gradient norm = 0.0002839
# [t-SNE] Iteration 156: error = 0.8410615, gradient norm = 0.0002802
# [t-SNE] Iteration 157: error = 0.8399799, gradient norm = 0.0002742
# [t-SNE] Iteration 158: error = 0.8389137, gradient norm = 0.0002711
# [t-SNE] Iteration 159: error = 0.8378613, gradient norm = 0.0002657
# [t-SNE] Iteration 160: error = 0.8368237, gradient norm = 0.0002622
# [t-SNE] Iteration 161: error = 0.8358004, gradient norm = 0.0002588
# [t-SNE] Iteration 162: error = 0.8347924, gradient norm = 0.0002602
# [t-SNE] Iteration 163: error = 0.8337969, gradient norm = 0.0002567
# [t-SNE] Iteration 164: error = 0.8328150, gradient norm = 0.0002530
# [t-SNE] Iteration 165: error = 0.8318468, gradient norm = 0.0002500
# [t-SNE] Iteration 166: error = 0.8308927, gradient norm = 0.0002477
# [t-SNE] Iteration 167: error = 0.8299522, gradient norm = 0.0002433
# [t-SNE] Iteration 168: error = 0.8290249, gradient norm = 0.0002350
# [t-SNE] Iteration 169: error = 0.8281123, gradient norm = 0.0002347
# [t-SNE] Iteration 170: error = 0.8272124, gradient norm = 0.0002319
# [t-SNE] Iteration 171: error = 0.8263240, gradient norm = 0.0002278
# [t-SNE] Iteration 172: error = 0.8254461, gradient norm = 0.0002255
# [t-SNE] Iteration 173: error = 0.8245779, gradient norm = 0.0002250
# [t-SNE] Iteration 174: error = 0.8237155, gradient norm = 0.0002265
# [t-SNE] Iteration 175: error = 0.8228559, gradient norm = 0.0002263
# [t-SNE] Iteration 176: error = 0.8220050, gradient norm = 0.0002249
# [t-SNE] Iteration 177: error = 0.8211669, gradient norm = 0.0002243
# [t-SNE] Iteration 178: error = 0.8203380, gradient norm = 0.0002236
# [t-SNE] Iteration 179: error = 0.8195246, gradient norm = 0.0002242
# [t-SNE] Iteration 180: error = 0.8187246, gradient norm = 0.0002305
# [t-SNE] Iteration 181: error = 0.8179305, gradient norm = 0.0002388
# [t-SNE] Iteration 182: error = 0.8171406, gradient norm = 0.0002446
# [t-SNE] Iteration 183: error = 0.8163532, gradient norm = 0.0002414
# [t-SNE] Iteration 184: error = 0.8155685, gradient norm = 0.0002260
# [t-SNE] Iteration 185: error = 0.8147929, gradient norm = 0.0002322
# [t-SNE] Iteration 186: error = 0.8140198, gradient norm = 0.0002394
# [t-SNE] Iteration 187: error = 0.8132497, gradient norm = 0.0002288
# [t-SNE] Iteration 188: error = 0.8124945, gradient norm = 0.0002281
# [t-SNE] Iteration 189: error = 0.8117537, gradient norm = 0.0002302
# [t-SNE] Iteration 190: error = 0.8110226, gradient norm = 0.0002276
# [t-SNE] Iteration 191: error = 0.8103011, gradient norm = 0.0002267
# [t-SNE] Iteration 192: error = 0.8095871, gradient norm = 0.0002185
# [t-SNE] Iteration 193: error = 0.8088858, gradient norm = 0.0002196
# [t-SNE] Iteration 194: error = 0.8081917, gradient norm = 0.0002135
# [t-SNE] Iteration 195: error = 0.8075062, gradient norm = 0.0002128
# [t-SNE] Iteration 196: error = 0.8068282, gradient norm = 0.0002091
# [t-SNE] Iteration 197: error = 0.8061583, gradient norm = 0.0002058
# [t-SNE] Iteration 198: error = 0.8054963, gradient norm = 0.0002035
# [t-SNE] Iteration 199: error = 0.8048416, gradient norm = 0.0002006
# [t-SNE] Iteration 200: error = 0.8041944, gradient norm = 0.0002009
# [t-SNE] Iteration 201: error = 0.8035533, gradient norm = 0.0001992
# [t-SNE] Iteration 202: error = 0.8029180, gradient norm = 0.0001965
# [t-SNE] Iteration 203: error = 0.8022884, gradient norm = 0.0001933
# [t-SNE] Iteration 204: error = 0.8016648, gradient norm = 0.0001927
# [t-SNE] Iteration 205: error = 0.8010463, gradient norm = 0.0001934
# [t-SNE] Iteration 206: error = 0.8004317, gradient norm = 0.0001922
# [t-SNE] Iteration 207: error = 0.7998209, gradient norm = 0.0001897
# [t-SNE] Iteration 208: error = 0.7992142, gradient norm = 0.0001905
# [t-SNE] Iteration 209: error = 0.7986101, gradient norm = 0.0001888
# [t-SNE] Iteration 210: error = 0.7980088, gradient norm = 0.0001865
# [t-SNE] Iteration 211: error = 0.7974108, gradient norm = 0.0001878
# [t-SNE] Iteration 212: error = 0.7968149, gradient norm = 0.0001877
# [t-SNE] Iteration 213: error = 0.7962205, gradient norm = 0.0001847
# [t-SNE] Iteration 214: error = 0.7956288, gradient norm = 0.0001845
# [t-SNE] Iteration 215: error = 0.7950393, gradient norm = 0.0001849
# [t-SNE] Iteration 216: error = 0.7944510, gradient norm = 0.0001834
# [t-SNE] Iteration 217: error = 0.7938645, gradient norm = 0.0001843
# [t-SNE] Iteration 218: error = 0.7932793, gradient norm = 0.0001871
# [t-SNE] Iteration 219: error = 0.7926953, gradient norm = 0.0001839
# [t-SNE] Iteration 220: error = 0.7921128, gradient norm = 0.0001825
# [t-SNE] Iteration 221: error = 0.7915323, gradient norm = 0.0001816
# [t-SNE] Iteration 222: error = 0.7909539, gradient norm = 0.0001807
# [t-SNE] Iteration 223: error = 0.7903767, gradient norm = 0.0001823
# [t-SNE] Iteration 224: error = 0.7898002, gradient norm = 0.0001803
# [t-SNE] Iteration 225: error = 0.7892243, gradient norm = 0.0001804
# [t-SNE] Iteration 226: error = 0.7886482, gradient norm = 0.0001819
# [t-SNE] Iteration 227: error = 0.7880716, gradient norm = 0.0001790
# [t-SNE] Iteration 228: error = 0.7874953, gradient norm = 0.0001783
# [t-SNE] Iteration 229: error = 0.7869208, gradient norm = 0.0001790
# [t-SNE] Iteration 230: error = 0.7863487, gradient norm = 0.0001776
# [t-SNE] Iteration 231: error = 0.7857809, gradient norm = 0.0001764
# [t-SNE] Iteration 232: error = 0.7852193, gradient norm = 0.0001743
# [t-SNE] Iteration 233: error = 0.7846644, gradient norm = 0.0001722
# [t-SNE] Iteration 234: error = 0.7841153, gradient norm = 0.0001687
# [t-SNE] Iteration 235: error = 0.7835709, gradient norm = 0.0001697
# [t-SNE] Iteration 236: error = 0.7830275, gradient norm = 0.0001756
# [t-SNE] Iteration 237: error = 0.7824801, gradient norm = 0.0001815
# [t-SNE] Iteration 238: error = 0.7819239, gradient norm = 0.0001897
# [t-SNE] Iteration 239: error = 0.7813584, gradient norm = 0.0001896
# [t-SNE] Iteration 240: error = 0.7807908, gradient norm = 0.0001839
# [t-SNE] Iteration 241: error = 0.7802304, gradient norm = 0.0001785
# [t-SNE] Iteration 242: error = 0.7796817, gradient norm = 0.0001776
# [t-SNE] Iteration 243: error = 0.7791409, gradient norm = 0.0001798
# [t-SNE] Iteration 244: error = 0.7786003, gradient norm = 0.0001854
# [t-SNE] Iteration 245: error = 0.7780537, gradient norm = 0.0001877
# [t-SNE] Iteration 246: error = 0.7774982, gradient norm = 0.0001956
# [t-SNE] Iteration 247: error = 0.7769368, gradient norm = 0.0001931
# [t-SNE] Iteration 248: error = 0.7763841, gradient norm = 0.0002022
# [t-SNE] Iteration 249: error = 0.7758683, gradient norm = 0.0001735
# [t-SNE] Iteration 250: error = 0.7754418, gradient norm = 0.0001838
# [t-SNE] Iteration 251: error = 0.7750947, gradient norm = 0.0002694
# [t-SNE] Iteration 252: error = 0.7746993, gradient norm = 0.0002905
# [t-SNE] Iteration 253: error = 0.7742396, gradient norm = 0.0002458
# [t-SNE] Iteration 254: error = 0.7737760, gradient norm = 0.0001861
# [t-SNE] Iteration 255: error = 0.7733456, gradient norm = 0.0001786
# [t-SNE] Iteration 256: error = 0.7729334, gradient norm = 0.0001784
# [t-SNE] Iteration 257: error = 0.7725266, gradient norm = 0.0001713
# [t-SNE] Iteration 258: error = 0.7721254, gradient norm = 0.0001729
# [t-SNE] Iteration 259: error = 0.7717270, gradient norm = 0.0001716
# [t-SNE] Iteration 260: error = 0.7713310, gradient norm = 0.0001649
# [t-SNE] Iteration 261: error = 0.7709383, gradient norm = 0.0001607
# [t-SNE] Iteration 262: error = 0.7705479, gradient norm = 0.0001605
# [t-SNE] Iteration 263: error = 0.7701586, gradient norm = 0.0001577
# [t-SNE] Iteration 264: error = 0.7697710, gradient norm = 0.0001528
# [t-SNE] Iteration 265: error = 0.7693865, gradient norm = 0.0001488
# [t-SNE] Iteration 266: error = 0.7690049, gradient norm = 0.0001468
# [t-SNE] Iteration 267: error = 0.7686262, gradient norm = 0.0001466
# [t-SNE] Iteration 268: error = 0.7682504, gradient norm = 0.0001483
# [t-SNE] Iteration 269: error = 0.7678769, gradient norm = 0.0001488
# [t-SNE] Iteration 270: error = 0.7675051, gradient norm = 0.0001445
# [t-SNE] Iteration 271: error = 0.7671364, gradient norm = 0.0001413
# [t-SNE] Iteration 272: error = 0.7667707, gradient norm = 0.0001408
# [t-SNE] Iteration 273: error = 0.7664072, gradient norm = 0.0001376
# [t-SNE] Iteration 274: error = 0.7660461, gradient norm = 0.0001353
# [t-SNE] Iteration 275: error = 0.7656874, gradient norm = 0.0001354
# [t-SNE] Iteration 276: error = 0.7653308, gradient norm = 0.0001359
# [t-SNE] Iteration 277: error = 0.7649754, gradient norm = 0.0001357
# [t-SNE] Iteration 278: error = 0.7646212, gradient norm = 0.0001363
# [t-SNE] Iteration 279: error = 0.7642676, gradient norm = 0.0001352
# [t-SNE] Iteration 280: error = 0.7639143, gradient norm = 0.0001352
# [t-SNE] Iteration 281: error = 0.7635607, gradient norm = 0.0001362
# [t-SNE] Iteration 282: error = 0.7632058, gradient norm = 0.0001332
# [t-SNE] Iteration 283: error = 0.7628497, gradient norm = 0.0001343
# [t-SNE] Iteration 284: error = 0.7624921, gradient norm = 0.0001361
# [t-SNE] Iteration 285: error = 0.7621339, gradient norm = 0.0001381
# [t-SNE] Iteration 286: error = 0.7617777, gradient norm = 0.0001428
# [t-SNE] Iteration 287: error = 0.7614255, gradient norm = 0.0001464
# [t-SNE] Iteration 288: error = 0.7610772, gradient norm = 0.0001506
# [t-SNE] Iteration 289: error = 0.7607287, gradient norm = 0.0001546
# [t-SNE] Iteration 290: error = 0.7603754, gradient norm = 0.0001553
# [t-SNE] Iteration 291: error = 0.7600156, gradient norm = 0.0001564
# [t-SNE] Iteration 292: error = 0.7596494, gradient norm = 0.0001566
# [t-SNE] Iteration 293: error = 0.7592781, gradient norm = 0.0001557
# [t-SNE] Iteration 294: error = 0.7589043, gradient norm = 0.0001520
# [t-SNE] Iteration 295: error = 0.7585326, gradient norm = 0.0001463
# [t-SNE] Iteration 296: error = 0.7581675, gradient norm = 0.0001393
# [t-SNE] Iteration 297: error = 0.7578136, gradient norm = 0.0001377
# [t-SNE] Iteration 298: error = 0.7574701, gradient norm = 0.0001432
# [t-SNE] Iteration 299: error = 0.7571315, gradient norm = 0.0001487
# [t-SNE] Iteration 300: error = 0.7567951, gradient norm = 0.0001500
# [t-SNE] Iteration 301: error = 0.7564600, gradient norm = 0.0001496
# [t-SNE] Iteration 302: error = 0.7561262, gradient norm = 0.0001474
# [t-SNE] Iteration 303: error = 0.7557947, gradient norm = 0.0001421
# [t-SNE] Iteration 304: error = 0.7554658, gradient norm = 0.0001381
# [t-SNE] Iteration 305: error = 0.7551392, gradient norm = 0.0001360
# [t-SNE] Iteration 306: error = 0.7548142, gradient norm = 0.0001344
# [t-SNE] Iteration 307: error = 0.7544900, gradient norm = 0.0001339
# [t-SNE] Iteration 308: error = 0.7541664, gradient norm = 0.0001335
# [t-SNE] Iteration 309: error = 0.7538431, gradient norm = 0.0001334
# [t-SNE] Iteration 310: error = 0.7535204, gradient norm = 0.0001338
# [t-SNE] Iteration 311: error = 0.7531982, gradient norm = 0.0001335
# [t-SNE] Iteration 312: error = 0.7528765, gradient norm = 0.0001333
# [t-SNE] Iteration 313: error = 0.7525556, gradient norm = 0.0001324
# [t-SNE] Iteration 314: error = 0.7522352, gradient norm = 0.0001333
# [t-SNE] Iteration 315: error = 0.7519150, gradient norm = 0.0001345
# [t-SNE] Iteration 316: error = 0.7515940, gradient norm = 0.0001344
# [t-SNE] Iteration 317: error = 0.7512721, gradient norm = 0.0001349
# [t-SNE] Iteration 318: error = 0.7509490, gradient norm = 0.0001354
# [t-SNE] Iteration 319: error = 0.7506244, gradient norm = 0.0001342
# [t-SNE] Iteration 320: error = 0.7502984, gradient norm = 0.0001349
# [t-SNE] Iteration 321: error = 0.7499702, gradient norm = 0.0001346
# [t-SNE] Iteration 322: error = 0.7496394, gradient norm = 0.0001347
# [t-SNE] Iteration 323: error = 0.7493042, gradient norm = 0.0001382
# [t-SNE] Iteration 324: error = 0.7489612, gradient norm = 0.0001451
# [t-SNE] Iteration 325: error = 0.7486052, gradient norm = 0.0001532
# [t-SNE] Iteration 326: error = 0.7482352, gradient norm = 0.0001536
# [t-SNE] Iteration 327: error = 0.7478645, gradient norm = 0.0001508
# [t-SNE] Iteration 328: error = 0.7475109, gradient norm = 0.0001587
# [t-SNE] Iteration 329: error = 0.7471699, gradient norm = 0.0001628
# [t-SNE] Iteration 330: error = 0.7468270, gradient norm = 0.0001672
# [t-SNE] Iteration 331: error = 0.7464770, gradient norm = 0.0001669
# [t-SNE] Iteration 332: error = 0.7461268, gradient norm = 0.0001579
# [t-SNE] Iteration 333: error = 0.7457956, gradient norm = 0.0001604
# [t-SNE] Iteration 334: error = 0.7454746, gradient norm = 0.0001723
# [t-SNE] Iteration 335: error = 0.7451348, gradient norm = 0.0001696
# [t-SNE] Iteration 336: error = 0.7447826, gradient norm = 0.0001588
# [t-SNE] Iteration 337: error = 0.7444387, gradient norm = 0.0001581
# [t-SNE] Iteration 338: error = 0.7441051, gradient norm = 0.0001672
# [t-SNE] Iteration 339: error = 0.7437696, gradient norm = 0.0001774
# [t-SNE] Iteration 340: error = 0.7434226, gradient norm = 0.0001800
# [t-SNE] Iteration 341: error = 0.7430653, gradient norm = 0.0001817
# [t-SNE] Iteration 342: error = 0.7426969, gradient norm = 0.0001909
# [t-SNE] Iteration 343: error = 0.7423177, gradient norm = 0.0001902
# [t-SNE] Iteration 344: error = 0.7419474, gradient norm = 0.0001892
# [t-SNE] Iteration 345: error = 0.7416031, gradient norm = 0.0001922
# [t-SNE] Iteration 346: error = 0.7412890, gradient norm = 0.0002052
# [t-SNE] Iteration 347: error = 0.7409775, gradient norm = 0.0002083
# [t-SNE] Iteration 348: error = 0.7406594, gradient norm = 0.0002086
# [t-SNE] Iteration 349: error = 0.7403333, gradient norm = 0.0001980
# [t-SNE] Iteration 350: error = 0.7400097, gradient norm = 0.0001686
# [t-SNE] Iteration 351: error = 0.7397089, gradient norm = 0.0001726
# [t-SNE] Iteration 352: error = 0.7394175, gradient norm = 0.0001871
# [t-SNE] Iteration 353: error = 0.7391224, gradient norm = 0.0001911
# [t-SNE] Iteration 354: error = 0.7388203, gradient norm = 0.0001812
# [t-SNE] Iteration 355: error = 0.7385170, gradient norm = 0.0001654
# [t-SNE] Iteration 356: error = 0.7382194, gradient norm = 0.0001541
# [t-SNE] Iteration 357: error = 0.7379289, gradient norm = 0.0001541
# [t-SNE] Iteration 358: error = 0.7376412, gradient norm = 0.0001582
# [t-SNE] Iteration 359: error = 0.7373529, gradient norm = 0.0001572
# [t-SNE] Iteration 360: error = 0.7370642, gradient norm = 0.0001510
# [t-SNE] Iteration 361: error = 0.7367771, gradient norm = 0.0001446
# [t-SNE] Iteration 362: error = 0.7364926, gradient norm = 0.0001389
# [t-SNE] Iteration 363: error = 0.7362113, gradient norm = 0.0001365
# [t-SNE] Iteration 364: error = 0.7359327, gradient norm = 0.0001369
# [t-SNE] Iteration 365: error = 0.7356556, gradient norm = 0.0001379
# [t-SNE] Iteration 366: error = 0.7353790, gradient norm = 0.0001383
# [t-SNE] Iteration 367: error = 0.7351021, gradient norm = 0.0001357
# [t-SNE] Iteration 368: error = 0.7348254, gradient norm = 0.0001325
# [t-SNE] Iteration 369: error = 0.7345500, gradient norm = 0.0001304
# [t-SNE] Iteration 370: error = 0.7342763, gradient norm = 0.0001289
# [t-SNE] Iteration 371: error = 0.7340046, gradient norm = 0.0001291
# [t-SNE] Iteration 372: error = 0.7337339, gradient norm = 0.0001277
# [t-SNE] Iteration 373: error = 0.7334639, gradient norm = 0.0001255
# [t-SNE] Iteration 374: error = 0.7331952, gradient norm = 0.0001256
# [t-SNE] Iteration 375: error = 0.7329277, gradient norm = 0.0001237
# [t-SNE] Iteration 376: error = 0.7326616, gradient norm = 0.0001227
# [t-SNE] Iteration 377: error = 0.7323969, gradient norm = 0.0001233
# [t-SNE] Iteration 378: error = 0.7321331, gradient norm = 0.0001232
# [t-SNE] Iteration 379: error = 0.7318699, gradient norm = 0.0001234
# [t-SNE] Iteration 380: error = 0.7316072, gradient norm = 0.0001233
# [t-SNE] Iteration 381: error = 0.7313443, gradient norm = 0.0001238
# [t-SNE] Iteration 382: error = 0.7310798, gradient norm = 0.0001257
# [t-SNE] Iteration 383: error = 0.7308114, gradient norm = 0.0001284
# [t-SNE] Iteration 384: error = 0.7305353, gradient norm = 0.0001329
# [t-SNE] Iteration 385: error = 0.7302474, gradient norm = 0.0001423
# [t-SNE] Iteration 386: error = 0.7299446, gradient norm = 0.0001539
# [t-SNE] Iteration 387: error = 0.7296233, gradient norm = 0.0001660
# [t-SNE] Iteration 388: error = 0.7292764, gradient norm = 0.0001748
# [t-SNE] Iteration 389: error = 0.7288943, gradient norm = 0.0001741
# [t-SNE] Iteration 390: error = 0.7285717, gradient norm = 0.0001703
# [t-SNE] Iteration 391: error = 0.7283059, gradient norm = 0.0002226
# [t-SNE] Iteration 392: error = 0.7279730, gradient norm = 0.0002074
# [t-SNE] Iteration 393: error = 0.7276188, gradient norm = 0.0001961
# [t-SNE] Iteration 394: error = 0.7273366, gradient norm = 0.0002172
# [t-SNE] Iteration 395: error = 0.7272673, gradient norm = 0.0003256
# [t-SNE] Iteration 396: error = 0.7270880, gradient norm = 0.0003214
# [t-SNE] Iteration 397: error = 0.7268270, gradient norm = 0.0002790
# [t-SNE] Iteration 398: error = 0.7266246, gradient norm = 0.0002483
# [t-SNE] Iteration 399: error = 0.7264307, gradient norm = 0.0002450
# [t-SNE] Iteration 400: error = 0.7262192, gradient norm = 0.0002134
# [t-SNE] Iteration 401: error = 0.7260334, gradient norm = 0.0002050
# [t-SNE] Iteration 402: error = 0.7258657, gradient norm = 0.0002111
# [t-SNE] Iteration 403: error = 0.7256872, gradient norm = 0.0001936
# [t-SNE] Iteration 404: error = 0.7255002, gradient norm = 0.0001720
# [t-SNE] Iteration 405: error = 0.7253139, gradient norm = 0.0001597
# [t-SNE] Iteration 406: error = 0.7251340, gradient norm = 0.0001559
# [t-SNE] Iteration 407: error = 0.7249586, gradient norm = 0.0001527
# [t-SNE] Iteration 408: error = 0.7247831, gradient norm = 0.0001442
# [t-SNE] Iteration 409: error = 0.7246067, gradient norm = 0.0001314
# [t-SNE] Iteration 410: error = 0.7244327, gradient norm = 0.0001195
# [t-SNE] Iteration 411: error = 0.7242651, gradient norm = 0.0001211
# [t-SNE] Iteration 412: error = 0.7241010, gradient norm = 0.0001296
# [t-SNE] Iteration 413: error = 0.7239358, gradient norm = 0.0001326
# [t-SNE] Iteration 414: error = 0.7237683, gradient norm = 0.0001283
# [t-SNE] Iteration 415: error = 0.7235991, gradient norm = 0.0001205
# [t-SNE] Iteration 416: error = 0.7234297, gradient norm = 0.0001135
# [t-SNE] Iteration 417: error = 0.7232611, gradient norm = 0.0001099
# [t-SNE] Iteration 418: error = 0.7230935, gradient norm = 0.0001080
# [t-SNE] Iteration 419: error = 0.7229269, gradient norm = 0.0001076
# [t-SNE] Iteration 420: error = 0.7227607, gradient norm = 0.0001075
# [t-SNE] Iteration 421: error = 0.7225945, gradient norm = 0.0001080
# [t-SNE] Iteration 422: error = 0.7224278, gradient norm = 0.0001078
# [t-SNE] Iteration 423: error = 0.7222606, gradient norm = 0.0001073
# [t-SNE] Iteration 424: error = 0.7220930, gradient norm = 0.0001064
# [t-SNE] Iteration 425: error = 0.7219251, gradient norm = 0.0001053
# [t-SNE] Iteration 426: error = 0.7217572, gradient norm = 0.0001064
# [t-SNE] Iteration 427: error = 0.7215890, gradient norm = 0.0001063
# [t-SNE] Iteration 428: error = 0.7214204, gradient norm = 0.0001056
# [t-SNE] Iteration 429: error = 0.7212517, gradient norm = 0.0001060
# [t-SNE] Iteration 430: error = 0.7210828, gradient norm = 0.0001073
# [t-SNE] Iteration 431: error = 0.7209133, gradient norm = 0.0001079
# [t-SNE] Iteration 432: error = 0.7207431, gradient norm = 0.0001073
# [t-SNE] Iteration 433: error = 0.7205724, gradient norm = 0.0001065
# [t-SNE] Iteration 434: error = 0.7204012, gradient norm = 0.0001056
# [t-SNE] Iteration 435: error = 0.7202297, gradient norm = 0.0001037
# [t-SNE] Iteration 436: error = 0.7200587, gradient norm = 0.0001023
# [t-SNE] Iteration 437: error = 0.7198887, gradient norm = 0.0001005
# [t-SNE] Iteration 438: error = 0.7197207, gradient norm = 0.0000979
# [t-SNE] Iteration 439: error = 0.7195558, gradient norm = 0.0000963
# [t-SNE] Iteration 440: error = 0.7193940, gradient norm = 0.0000950
# [t-SNE] Iteration 441: error = 0.7192350, gradient norm = 0.0000945
# [t-SNE] Iteration 442: error = 0.7190779, gradient norm = 0.0000950
# [t-SNE] Iteration 443: error = 0.7189221, gradient norm = 0.0000945
# [t-SNE] Iteration 444: error = 0.7187676, gradient norm = 0.0000932
# [t-SNE] Iteration 445: error = 0.7186147, gradient norm = 0.0000918
# [t-SNE] Iteration 446: error = 0.7184637, gradient norm = 0.0000908
# [t-SNE] Iteration 447: error = 0.7183145, gradient norm = 0.0000897
# [t-SNE] Iteration 448: error = 0.7181671, gradient norm = 0.0000882
# [t-SNE] Iteration 449: error = 0.7180216, gradient norm = 0.0000864
# [t-SNE] Iteration 450: error = 0.7178784, gradient norm = 0.0000847
# [t-SNE] Iteration 451: error = 0.7177377, gradient norm = 0.0000827
# [t-SNE] Iteration 452: error = 0.7175998, gradient norm = 0.0000818
# [t-SNE] Iteration 453: error = 0.7174646, gradient norm = 0.0000804
# [t-SNE] Iteration 454: error = 0.7173323, gradient norm = 0.0000792
# [t-SNE] Iteration 455: error = 0.7172029, gradient norm = 0.0000773
# [t-SNE] Iteration 456: error = 0.7170765, gradient norm = 0.0000763
# [t-SNE] Iteration 457: error = 0.7169531, gradient norm = 0.0000759
# [t-SNE] Iteration 458: error = 0.7168325, gradient norm = 0.0000732
# [t-SNE] Iteration 459: error = 0.7167148, gradient norm = 0.0000720
# [t-SNE] Iteration 460: error = 0.7166000, gradient norm = 0.0000717
# [t-SNE] Iteration 461: error = 0.7164877, gradient norm = 0.0000703
# [t-SNE] Iteration 462: error = 0.7163780, gradient norm = 0.0000697
# [t-SNE] Iteration 463: error = 0.7162707, gradient norm = 0.0000701
# [t-SNE] Iteration 464: error = 0.7161655, gradient norm = 0.0000686
# [t-SNE] Iteration 465: error = 0.7160623, gradient norm = 0.0000666
# [t-SNE] Iteration 466: error = 0.7159612, gradient norm = 0.0000667
# [t-SNE] Iteration 467: error = 0.7158618, gradient norm = 0.0000666
# [t-SNE] Iteration 468: error = 0.7157637, gradient norm = 0.0000656
# [t-SNE] Iteration 469: error = 0.7156671, gradient norm = 0.0000652
# [t-SNE] Iteration 470: error = 0.7155717, gradient norm = 0.0000660
# [t-SNE] Iteration 471: error = 0.7154774, gradient norm = 0.0000647
# [t-SNE] Iteration 472: error = 0.7153844, gradient norm = 0.0000647
# [t-SNE] Iteration 473: error = 0.7152927, gradient norm = 0.0000658
# [t-SNE] Iteration 474: error = 0.7152020, gradient norm = 0.0000659
# [t-SNE] Iteration 475: error = 0.7151121, gradient norm = 0.0000649
# [t-SNE] Iteration 476: error = 0.7150229, gradient norm = 0.0000630
# [t-SNE] Iteration 477: error = 0.7149344, gradient norm = 0.0000621
# [t-SNE] Iteration 478: error = 0.7148467, gradient norm = 0.0000612
# [t-SNE] Iteration 479: error = 0.7147596, gradient norm = 0.0000604
# [t-SNE] Iteration 480: error = 0.7146731, gradient norm = 0.0000599
# [t-SNE] Iteration 481: error = 0.7145871, gradient norm = 0.0000603
# [t-SNE] Iteration 482: error = 0.7145016, gradient norm = 0.0000606
# [t-SNE] Iteration 483: error = 0.7144164, gradient norm = 0.0000599
# [t-SNE] Iteration 484: error = 0.7143315, gradient norm = 0.0000593
# [t-SNE] Iteration 485: error = 0.7142471, gradient norm = 0.0000585
# [t-SNE] Iteration 486: error = 0.7141631, gradient norm = 0.0000587
# [t-SNE] Iteration 487: error = 0.7140794, gradient norm = 0.0000588
# [t-SNE] Iteration 488: error = 0.7139961, gradient norm = 0.0000584
# [t-SNE] Iteration 489: error = 0.7139133, gradient norm = 0.0000583
# [t-SNE] Iteration 490: error = 0.7138308, gradient norm = 0.0000589
# [t-SNE] Iteration 491: error = 0.7137486, gradient norm = 0.0000588
# [t-SNE] Iteration 492: error = 0.7136668, gradient norm = 0.0000580
# [t-SNE] Iteration 493: error = 0.7135855, gradient norm = 0.0000580
# [t-SNE] Iteration 494: error = 0.7135045, gradient norm = 0.0000581
# [t-SNE] Iteration 495: error = 0.7134239, gradient norm = 0.0000581
# [t-SNE] Iteration 496: error = 0.7133436, gradient norm = 0.0000581
# [t-SNE] Iteration 497: error = 0.7132638, gradient norm = 0.0000579
# [t-SNE] Iteration 498: error = 0.7131843, gradient norm = 0.0000569
# [t-SNE] Iteration 499: error = 0.7131053, gradient norm = 0.0000564
# [t-SNE] Iteration 500: error = 0.7130268, gradient norm = 0.0000566
# [t-SNE] Iteration 501: error = 0.7129487, gradient norm = 0.0000560
# [t-SNE] Iteration 502: error = 0.7128709, gradient norm = 0.0000555
# [t-SNE] Iteration 503: error = 0.7127935, gradient norm = 0.0000555
# [t-SNE] Iteration 504: error = 0.7127166, gradient norm = 0.0000553
# [t-SNE] Iteration 505: error = 0.7126399, gradient norm = 0.0000551
# [t-SNE] Iteration 506: error = 0.7125637, gradient norm = 0.0000556
# [t-SNE] Iteration 507: error = 0.7124877, gradient norm = 0.0000554
# [t-SNE] Iteration 508: error = 0.7124119, gradient norm = 0.0000546
# [t-SNE] Iteration 509: error = 0.7123366, gradient norm = 0.0000545
# [t-SNE] Iteration 510: error = 0.7122616, gradient norm = 0.0000553
# [t-SNE] Iteration 511: error = 0.7121868, gradient norm = 0.0000546
# [t-SNE] Iteration 512: error = 0.7121123, gradient norm = 0.0000538
# [t-SNE] Iteration 513: error = 0.7120382, gradient norm = 0.0000538
# [t-SNE] Iteration 514: error = 0.7119645, gradient norm = 0.0000534
# [t-SNE] Iteration 515: error = 0.7118910, gradient norm = 0.0000535
# [t-SNE] Iteration 516: error = 0.7118179, gradient norm = 0.0000541
# [t-SNE] Iteration 517: error = 0.7117449, gradient norm = 0.0000537
# [t-SNE] Iteration 518: error = 0.7116723, gradient norm = 0.0000537
# [t-SNE] Iteration 519: error = 0.7115999, gradient norm = 0.0000537
# [t-SNE] Iteration 520: error = 0.7115278, gradient norm = 0.0000536
# [t-SNE] Iteration 521: error = 0.7114559, gradient norm = 0.0000530
# [t-SNE] Iteration 522: error = 0.7113844, gradient norm = 0.0000529
# [t-SNE] Iteration 523: error = 0.7113131, gradient norm = 0.0000531
# [t-SNE] Iteration 524: error = 0.7112421, gradient norm = 0.0000527
# [t-SNE] Iteration 525: error = 0.7111714, gradient norm = 0.0000523
# [t-SNE] Iteration 526: error = 0.7111010, gradient norm = 0.0000517
# [t-SNE] Iteration 527: error = 0.7110308, gradient norm = 0.0000513
# [t-SNE] Iteration 528: error = 0.7109608, gradient norm = 0.0000516
# [t-SNE] Iteration 529: error = 0.7108910, gradient norm = 0.0000511
# [t-SNE] Iteration 530: error = 0.7108215, gradient norm = 0.0000511
# [t-SNE] Iteration 531: error = 0.7107521, gradient norm = 0.0000516
# [t-SNE] Iteration 532: error = 0.7106830, gradient norm = 0.0000514
# [t-SNE] Iteration 533: error = 0.7106140, gradient norm = 0.0000509
# [t-SNE] Iteration 534: error = 0.7105453, gradient norm = 0.0000509
# [t-SNE] Iteration 535: error = 0.7104767, gradient norm = 0.0000506
# [t-SNE] Iteration 536: error = 0.7104084, gradient norm = 0.0000506
# [t-SNE] Iteration 537: error = 0.7103403, gradient norm = 0.0000507
# [t-SNE] Iteration 538: error = 0.7102725, gradient norm = 0.0000519
# [t-SNE] Iteration 539: error = 0.7102048, gradient norm = 0.0000520
# [t-SNE] Iteration 540: error = 0.7101374, gradient norm = 0.0000521
# [t-SNE] Iteration 541: error = 0.7100702, gradient norm = 0.0000520
# [t-SNE] Iteration 542: error = 0.7100033, gradient norm = 0.0000510
# [t-SNE] Iteration 543: error = 0.7099368, gradient norm = 0.0000510
# [t-SNE] Iteration 544: error = 0.7098706, gradient norm = 0.0000515
# [t-SNE] Iteration 545: error = 0.7098045, gradient norm = 0.0000509
# [t-SNE] Iteration 546: error = 0.7097388, gradient norm = 0.0000502
# [t-SNE] Iteration 547: error = 0.7096733, gradient norm = 0.0000502
# [t-SNE] Iteration 548: error = 0.7096081, gradient norm = 0.0000500
# [t-SNE] Iteration 549: error = 0.7095431, gradient norm = 0.0000501
# [t-SNE] Iteration 550: error = 0.7094783, gradient norm = 0.0000503
# [t-SNE] Iteration 551: error = 0.7094136, gradient norm = 0.0000502
# [t-SNE] Iteration 552: error = 0.7093491, gradient norm = 0.0000499
# [t-SNE] Iteration 553: error = 0.7092848, gradient norm = 0.0000503
# [t-SNE] Iteration 554: error = 0.7092206, gradient norm = 0.0000508
# [t-SNE] Iteration 555: error = 0.7091566, gradient norm = 0.0000506
# [t-SNE] Iteration 556: error = 0.7090927, gradient norm = 0.0000501
# [t-SNE] Iteration 557: error = 0.7090290, gradient norm = 0.0000496
# [t-SNE] Iteration 558: error = 0.7089655, gradient norm = 0.0000492
# [t-SNE] Iteration 559: error = 0.7089023, gradient norm = 0.0000493
# [t-SNE] Iteration 560: error = 0.7088393, gradient norm = 0.0000493
# [t-SNE] Iteration 561: error = 0.7087765, gradient norm = 0.0000489
# [t-SNE] Iteration 562: error = 0.7087140, gradient norm = 0.0000490
# [t-SNE] Iteration 563: error = 0.7086516, gradient norm = 0.0000486
# [t-SNE] Iteration 564: error = 0.7085896, gradient norm = 0.0000483
# [t-SNE] Iteration 565: error = 0.7085278, gradient norm = 0.0000482
# [t-SNE] Iteration 566: error = 0.7084662, gradient norm = 0.0000480
# [t-SNE] Iteration 567: error = 0.7084048, gradient norm = 0.0000478
# [t-SNE] Iteration 568: error = 0.7083437, gradient norm = 0.0000485
# [t-SNE] Iteration 569: error = 0.7082829, gradient norm = 0.0000502
# [t-SNE] Iteration 570: error = 0.7082222, gradient norm = 0.0000499
# [t-SNE] Iteration 571: error = 0.7081616, gradient norm = 0.0000471
# [t-SNE] Iteration 572: error = 0.7081014, gradient norm = 0.0000470
# [t-SNE] Iteration 573: error = 0.7080415, gradient norm = 0.0000480
# [t-SNE] Iteration 574: error = 0.7079818, gradient norm = 0.0000471
# [t-SNE] Iteration 575: error = 0.7079224, gradient norm = 0.0000482
# [t-SNE] Iteration 576: error = 0.7078631, gradient norm = 0.0000474
# [t-SNE] Iteration 577: error = 0.7078042, gradient norm = 0.0000484
# [t-SNE] Iteration 578: error = 0.7077455, gradient norm = 0.0000478
# [t-SNE] Iteration 579: error = 0.7076871, gradient norm = 0.0000477
# [t-SNE] Iteration 580: error = 0.7076290, gradient norm = 0.0000474
# [t-SNE] Iteration 581: error = 0.7075714, gradient norm = 0.0000476
# [t-SNE] Iteration 582: error = 0.7075140, gradient norm = 0.0000477
# [t-SNE] Iteration 583: error = 0.7074569, gradient norm = 0.0000466
# [t-SNE] Iteration 584: error = 0.7074002, gradient norm = 0.0000465
# [t-SNE] Iteration 585: error = 0.7073438, gradient norm = 0.0000466
# [t-SNE] Iteration 586: error = 0.7072877, gradient norm = 0.0000459
# [t-SNE] Iteration 587: error = 0.7072319, gradient norm = 0.0000458
# [t-SNE] Iteration 588: error = 0.7071764, gradient norm = 0.0000457
# [t-SNE] Iteration 589: error = 0.7071211, gradient norm = 0.0000453
# [t-SNE] Iteration 590: error = 0.7070659, gradient norm = 0.0000452
# [t-SNE] Iteration 591: error = 0.7070110, gradient norm = 0.0000446
# [t-SNE] Iteration 592: error = 0.7069562, gradient norm = 0.0000445
# [t-SNE] Iteration 593: error = 0.7069017, gradient norm = 0.0000451
# [t-SNE] Iteration 594: error = 0.7068472, gradient norm = 0.0000449
# [t-SNE] Iteration 595: error = 0.7067929, gradient norm = 0.0000447
# [t-SNE] Iteration 596: error = 0.7067387, gradient norm = 0.0000444
# [t-SNE] Iteration 597: error = 0.7066847, gradient norm = 0.0000443
# [t-SNE] Iteration 598: error = 0.7066308, gradient norm = 0.0000441
# [t-SNE] Iteration 599: error = 0.7065770, gradient norm = 0.0000437
# [t-SNE] Iteration 600: error = 0.7065234, gradient norm = 0.0000443
# [t-SNE] Iteration 601: error = 0.7064700, gradient norm = 0.0000445
# [t-SNE] Iteration 602: error = 0.7064166, gradient norm = 0.0000445
# [t-SNE] Iteration 603: error = 0.7063634, gradient norm = 0.0000441
# [t-SNE] Iteration 604: error = 0.7063103, gradient norm = 0.0000439
# [t-SNE] Iteration 605: error = 0.7062573, gradient norm = 0.0000440
# [t-SNE] Iteration 606: error = 0.7062044, gradient norm = 0.0000442
# [t-SNE] Iteration 607: error = 0.7061516, gradient norm = 0.0000446
# [t-SNE] Iteration 608: error = 0.7060988, gradient norm = 0.0000450
# [t-SNE] Iteration 609: error = 0.7060461, gradient norm = 0.0000449
# [t-SNE] Iteration 610: error = 0.7059934, gradient norm = 0.0000447
# [t-SNE] Iteration 611: error = 0.7059410, gradient norm = 0.0000447
# [t-SNE] Iteration 612: error = 0.7058889, gradient norm = 0.0000449
# [t-SNE] Iteration 613: error = 0.7058372, gradient norm = 0.0000451
# [t-SNE] Iteration 614: error = 0.7057857, gradient norm = 0.0000451
# [t-SNE] Iteration 615: error = 0.7057344, gradient norm = 0.0000448
# [t-SNE] Iteration 616: error = 0.7056833, gradient norm = 0.0000451
# [t-SNE] Iteration 617: error = 0.7056323, gradient norm = 0.0000447
# [t-SNE] Iteration 618: error = 0.7055814, gradient norm = 0.0000444
# [t-SNE] Iteration 619: error = 0.7055306, gradient norm = 0.0000445
# [t-SNE] Iteration 620: error = 0.7054795, gradient norm = 0.0000457
# [t-SNE] Iteration 621: error = 0.7054279, gradient norm = 0.0000482
# [t-SNE] Iteration 622: error = 0.7053774, gradient norm = 0.0000535
# [t-SNE] Iteration 623: error = 0.7053275, gradient norm = 0.0000543
# [t-SNE] Iteration 624: error = 0.7052771, gradient norm = 0.0000494
# [t-SNE] Iteration 625: error = 0.7052283, gradient norm = 0.0000505
# [t-SNE] Iteration 626: error = 0.7051794, gradient norm = 0.0000491
# [t-SNE] Iteration 627: error = 0.7051305, gradient norm = 0.0000465
# [t-SNE] Iteration 628: error = 0.7050823, gradient norm = 0.0000466
# [t-SNE] Iteration 629: error = 0.7050342, gradient norm = 0.0000464
# [t-SNE] Iteration 630: error = 0.7049862, gradient norm = 0.0000462
# [t-SNE] Iteration 631: error = 0.7049386, gradient norm = 0.0000462
# [t-SNE] Iteration 632: error = 0.7048911, gradient norm = 0.0000456
# [t-SNE] Iteration 633: error = 0.7048436, gradient norm = 0.0000443
# [t-SNE] Iteration 634: error = 0.7047963, gradient norm = 0.0000436
# [t-SNE] Iteration 635: error = 0.7047490, gradient norm = 0.0000430
# [t-SNE] Iteration 636: error = 0.7047018, gradient norm = 0.0000420
# [t-SNE] Iteration 637: error = 0.7046548, gradient norm = 0.0000421
# [t-SNE] Iteration 638: error = 0.7046080, gradient norm = 0.0000425
# [t-SNE] Iteration 639: error = 0.7045612, gradient norm = 0.0000421
# [t-SNE] Iteration 640: error = 0.7045145, gradient norm = 0.0000420
# [t-SNE] Iteration 641: error = 0.7044679, gradient norm = 0.0000420
# [t-SNE] Iteration 642: error = 0.7044214, gradient norm = 0.0000416
# [t-SNE] Iteration 643: error = 0.7043750, gradient norm = 0.0000412
# [t-SNE] Iteration 644: error = 0.7043286, gradient norm = 0.0000412
# [t-SNE] Iteration 645: error = 0.7042822, gradient norm = 0.0000414
# [t-SNE] Iteration 646: error = 0.7042359, gradient norm = 0.0000417
# [t-SNE] Iteration 647: error = 0.7041896, gradient norm = 0.0000421
# [t-SNE] Iteration 648: error = 0.7041433, gradient norm = 0.0000420
# [t-SNE] Iteration 649: error = 0.7040970, gradient norm = 0.0000416
# [t-SNE] Iteration 650: error = 0.7040508, gradient norm = 0.0000416
# [t-SNE] Iteration 651: error = 0.7040046, gradient norm = 0.0000413
# [t-SNE] Iteration 652: error = 0.7039584, gradient norm = 0.0000410
# [t-SNE] Iteration 653: error = 0.7039122, gradient norm = 0.0000411
# [t-SNE] Iteration 654: error = 0.7038660, gradient norm = 0.0000416
# [t-SNE] Iteration 655: error = 0.7038198, gradient norm = 0.0000419
# [t-SNE] Iteration 656: error = 0.7037734, gradient norm = 0.0000414
# [t-SNE] Iteration 657: error = 0.7037271, gradient norm = 0.0000415
# [t-SNE] Iteration 658: error = 0.7036807, gradient norm = 0.0000422
# [t-SNE] Iteration 659: error = 0.7036342, gradient norm = 0.0000422
# [t-SNE] Iteration 660: error = 0.7035876, gradient norm = 0.0000430
# [t-SNE] Iteration 661: error = 0.7035408, gradient norm = 0.0000432
# [t-SNE] Iteration 662: error = 0.7034939, gradient norm = 0.0000432
# [t-SNE] Iteration 663: error = 0.7034468, gradient norm = 0.0000438
# [t-SNE] Iteration 664: error = 0.7033994, gradient norm = 0.0000442
# [t-SNE] Iteration 665: error = 0.7033517, gradient norm = 0.0000449
# [t-SNE] Iteration 666: error = 0.7033035, gradient norm = 0.0000458
# [t-SNE] Iteration 667: error = 0.7032547, gradient norm = 0.0000455
# [t-SNE] Iteration 668: error = 0.7032049, gradient norm = 0.0000465
# [t-SNE] Iteration 669: error = 0.7031542, gradient norm = 0.0000474
# [t-SNE] Iteration 670: error = 0.7031018, gradient norm = 0.0000492
# [t-SNE] Iteration 671: error = 0.7030474, gradient norm = 0.0000504
# [t-SNE] Iteration 672: error = 0.7029905, gradient norm = 0.0000530
# [t-SNE] Iteration 673: error = 0.7029304, gradient norm = 0.0000554
# [t-SNE] Iteration 674: error = 0.7028669, gradient norm = 0.0000581
# [t-SNE] Iteration 675: error = 0.7028002, gradient norm = 0.0000609
# [t-SNE] Iteration 676: error = 0.7027313, gradient norm = 0.0000651
# [t-SNE] Iteration 677: error = 0.7026606, gradient norm = 0.0000714
# [t-SNE] Iteration 678: error = 0.7025876, gradient norm = 0.0000755
# [t-SNE] Iteration 679: error = 0.7025126, gradient norm = 0.0000746
# [t-SNE] Iteration 680: error = 0.7024382, gradient norm = 0.0000689
# [t-SNE] Iteration 681: error = 0.7023694, gradient norm = 0.0000616
# [t-SNE] Iteration 682: error = 0.7023109, gradient norm = 0.0000632
# [t-SNE] Iteration 683: error = 0.7022613, gradient norm = 0.0000760
# [t-SNE] Iteration 684: error = 0.7022117, gradient norm = 0.0000868
# [t-SNE] Iteration 685: error = 0.7021568, gradient norm = 0.0000846
# [t-SNE] Iteration 686: error = 0.7021019, gradient norm = 0.0000766
# [t-SNE] Iteration 687: error = 0.7020514, gradient norm = 0.0000732
# [t-SNE] Iteration 688: error = 0.7020034, gradient norm = 0.0000677
# [t-SNE] Iteration 689: error = 0.7019566, gradient norm = 0.0000597
# [t-SNE] Iteration 690: error = 0.7019121, gradient norm = 0.0000568
# [t-SNE] Iteration 691: error = 0.7018703, gradient norm = 0.0000629
# [t-SNE] Iteration 692: error = 0.7018290, gradient norm = 0.0000709
# [t-SNE] Iteration 693: error = 0.7017860, gradient norm = 0.0000692
# ...
# [t-SNE] Iteration 766: error = 0.6990037, gradient norm = 0.0000370
# [t-SNE] Iteration 767: error = 0.6989687, gradient norm = 0.0000369
# [t-SNE] Iteration 768: error = 0.6989338, gradient norm = 0.0000373
# [t-SNE] Iteration 769: error = 0.6988989, gradient norm = 0.0000374
# [t-SNE] Iteration 770: error = 0.6988639, gradient norm = 0.0000376
# [t-SNE] Iteration 771: error = 0.6988290, gradient norm = 0.0000376
# [t-SNE] Iteration 772: error = 0.6987940, gradient norm = 0.0000379
# [t-SNE] Iteration 773: error = 0.6987591, gradient norm = 0.0000376
# [t-SNE] Iteration 774: error = 0.6987243, gradient norm = 0.0000373
# [t-SNE] Iteration 775: error = 0.6986895, gradient norm = 0.0000375
# [t-SNE] Iteration 776: error = 0.6986547, gradient norm = 0.0000372
# [t-SNE] Iteration 777: error = 0.6986200, gradient norm = 0.0000370
# [t-SNE] Iteration 778: error = 0.6985854, gradient norm = 0.0000365
# [t-SNE] Iteration 779: error = 0.6985508, gradient norm = 0.0000365
# [t-SNE] Iteration 780: error = 0.6985162, gradient norm = 0.0000363
# [t-SNE] Iteration 781: error = 0.6984816, gradient norm = 0.0000360
# [t-SNE] Iteration 782: error = 0.6984471, gradient norm = 0.0000360
# [t-SNE] Iteration 783: error = 0.6984125, gradient norm = 0.0000358
# [t-SNE] Iteration 784: error = 0.6983779, gradient norm = 0.0000356
# [t-SNE] Iteration 785: error = 0.6983432, gradient norm = 0.0000355
# [t-SNE] Iteration 786: error = 0.6983086, gradient norm = 0.0000357
# [t-SNE] Iteration 787: error = 0.6982739, gradient norm = 0.0000358
# [t-SNE] Iteration 788: error = 0.6982391, gradient norm = 0.0000362
# [t-SNE] Iteration 789: error = 0.6982043, gradient norm = 0.0000362
# [t-SNE] Iteration 790: error = 0.6981694, gradient norm = 0.0000356
# [t-SNE] Iteration 791: error = 0.6981346, gradient norm = 0.0000357
# [t-SNE] Iteration 792: error = 0.6980998, gradient norm = 0.0000360
# [t-SNE] Iteration 793: error = 0.6980649, gradient norm = 0.0000361
# [t-SNE] Iteration 794: error = 0.6980299, gradient norm = 0.0000357
# [t-SNE] Iteration 795: error = 0.6979950, gradient norm = 0.0000355
# [t-SNE] Iteration 796: error = 0.6979600, gradient norm = 0.0000356
# [t-SNE] Iteration 797: error = 0.6979250, gradient norm = 0.0000355
# [t-SNE] Iteration 798: error = 0.6978899, gradient norm = 0.0000354
# [t-SNE] Iteration 799: error = 0.6978548, gradient norm = 0.0000355
# [t-SNE] Iteration 800: error = 0.6978197, gradient norm = 0.0000358
# [t-SNE] Iteration 801: error = 0.6977845, gradient norm = 0.0000358
# [t-SNE] Iteration 802: error = 0.6977493, gradient norm = 0.0000363
# [t-SNE] Iteration 803: error = 0.6977140, gradient norm = 0.0000364
# [t-SNE] Iteration 804: error = 0.6976786, gradient norm = 0.0000363
# [t-SNE] Iteration 805: error = 0.6976433, gradient norm = 0.0000362
# [t-SNE] Iteration 806: error = 0.6976079, gradient norm = 0.0000365
# [t-SNE] Iteration 807: error = 0.6975725, gradient norm = 0.0000366
# [t-SNE] Iteration 808: error = 0.6975372, gradient norm = 0.0000380
# [t-SNE] Iteration 809: error = 0.6975017, gradient norm = 0.0000376
# [t-SNE] Iteration 810: error = 0.6974662, gradient norm = 0.0000365
# [t-SNE] Iteration 811: error = 0.6974308, gradient norm = 0.0000361
# [t-SNE] Iteration 812: error = 0.6973954, gradient norm = 0.0000367
# [t-SNE] Iteration 813: error = 0.6973599, gradient norm = 0.0000364
# [t-SNE] Iteration 814: error = 0.6973245, gradient norm = 0.0000371
# [t-SNE] Iteration 815: error = 0.6972891, gradient norm = 0.0000378
# [t-SNE] Iteration 816: error = 0.6972535, gradient norm = 0.0000367
# [t-SNE] Iteration 817: error = 0.6972179, gradient norm = 0.0000363
# [t-SNE] Iteration 818: error = 0.6971823, gradient norm = 0.0000372
# [t-SNE] Iteration 819: error = 0.6971467, gradient norm = 0.0000373
# [t-SNE] Iteration 820: error = 0.6971110, gradient norm = 0.0000375
# [t-SNE] Iteration 821: error = 0.6970754, gradient norm = 0.0000383
# [t-SNE] Iteration 822: error = 0.6970397, gradient norm = 0.0000387
# [t-SNE] Iteration 823: error = 0.6970040, gradient norm = 0.0000382
# [t-SNE] Iteration 824: error = 0.6969684, gradient norm = 0.0000380
# [t-SNE] Iteration 825: error = 0.6969329, gradient norm = 0.0000379
# [t-SNE] Iteration 826: error = 0.6968975, gradient norm = 0.0000368
# [t-SNE] Iteration 827: error = 0.6968621, gradient norm = 0.0000369
# [t-SNE] Iteration 828: error = 0.6968268, gradient norm = 0.0000372
# [t-SNE] Iteration 829: error = 0.6967915, gradient norm = 0.0000361
# [t-SNE] Iteration 830: error = 0.6967562, gradient norm = 0.0000364
# [t-SNE] Iteration 831: error = 0.6967209, gradient norm = 0.0000364
# [t-SNE] Iteration 832: error = 0.6966855, gradient norm = 0.0000363
# [t-SNE] Iteration 833: error = 0.6966500, gradient norm = 0.0000364
# [t-SNE] Iteration 834: error = 0.6966144, gradient norm = 0.0000364
# [t-SNE] Iteration 835: error = 0.6965785, gradient norm = 0.0000368
# [t-SNE] Iteration 836: error = 0.6965425, gradient norm = 0.0000369
# [t-SNE] Iteration 837: error = 0.6965061, gradient norm = 0.0000369
# [t-SNE] Iteration 838: error = 0.6964692, gradient norm = 0.0000382
# [t-SNE] Iteration 839: error = 0.6964313, gradient norm = 0.0000399
# [t-SNE] Iteration 840: error = 0.6963915, gradient norm = 0.0000444
# [t-SNE] Iteration 841: error = 0.6963475, gradient norm = 0.0000533
# [t-SNE] Iteration 842: error = 0.6962939, gradient norm = 0.0000649
# [t-SNE] Iteration 843: error = 0.6962300, gradient norm = 0.0000664
# [t-SNE] Iteration 844: error = 0.6961832, gradient norm = 0.0000918
# [t-SNE] Iteration 845: error = 0.6961504, gradient norm = 0.0000961
# [t-SNE] Iteration 846: error = 0.6961110, gradient norm = 0.0000884
# [t-SNE] Iteration 847: error = 0.6960629, gradient norm = 0.0000827
# [t-SNE] Iteration 848: error = 0.6960107, gradient norm = 0.0000681
# [t-SNE] Iteration 849: error = 0.6959667, gradient norm = 0.0000646
# [t-SNE] Iteration 850: error = 0.6959306, gradient norm = 0.0000896
# [t-SNE] Iteration 851: error = 0.6958864, gradient norm = 0.0000865
# [t-SNE] Iteration 852: error = 0.6958362, gradient norm = 0.0000592
# [t-SNE] Iteration 853: error = 0.6957904, gradient norm = 0.0000572
# [t-SNE] Iteration 854: error = 0.6957459, gradient norm = 0.0000705
# [t-SNE] Iteration 855: error = 0.6956953, gradient norm = 0.0000770
# [t-SNE] Iteration 856: error = 0.6956346, gradient norm = 0.0000789
# [t-SNE] Iteration 857: error = 0.6955612, gradient norm = 0.0000850
# [t-SNE] Iteration 858: error = 0.6954740, gradient norm = 0.0000953
# [t-SNE] Iteration 859: error = 0.6953778, gradient norm = 0.0001021
# [t-SNE] Iteration 860: error = 0.6952878, gradient norm = 0.0001052
# [t-SNE] Iteration 861: error = 0.6952162, gradient norm = 0.0001156
# [t-SNE] Iteration 862: error = 0.6951472, gradient norm = 0.0001172
# [t-SNE] Iteration 863: error = 0.6950781, gradient norm = 0.0001122
# [t-SNE] Iteration 864: error = 0.6950130, gradient norm = 0.0000971
# [t-SNE] Iteration 865: error = 0.6949596, gradient norm = 0.0000965
# [t-SNE] Iteration 866: error = 0.6949131, gradient norm = 0.0001135
# [t-SNE] Iteration 867: error = 0.6948577, gradient norm = 0.0000860
# [t-SNE] Iteration 868: error = 0.6948064, gradient norm = 0.0000658
# [t-SNE] Iteration 869: error = 0.6947633, gradient norm = 0.0000761
# [t-SNE] Iteration 870: error = 0.6947194, gradient norm = 0.0000765
# [t-SNE] Iteration 871: error = 0.6946738, gradient norm = 0.0000687
# [t-SNE] Iteration 872: error = 0.6946294, gradient norm = 0.0000622
# [t-SNE] Iteration 873: error = 0.6945870, gradient norm = 0.0000584
# [t-SNE] Iteration 874: error = 0.6945460, gradient norm = 0.0000568
# [t-SNE] Iteration 875: error = 0.6945059, gradient norm = 0.0000585
# [t-SNE] Iteration 876: error = 0.6944661, gradient norm = 0.0000605
# [t-SNE] Iteration 877: error = 0.6944261, gradient norm = 0.0000580
# [t-SNE] Iteration 878: error = 0.6943862, gradient norm = 0.0000529
# [t-SNE] Iteration 879: error = 0.6943467, gradient norm = 0.0000473
# [t-SNE] Iteration 880: error = 0.6943078, gradient norm = 0.0000458
# [t-SNE] Iteration 881: error = 0.6942693, gradient norm = 0.0000469
# [t-SNE] Iteration 882: error = 0.6942310, gradient norm = 0.0000470
# [t-SNE] Iteration 883: error = 0.6941928, gradient norm = 0.0000463
# [t-SNE] Iteration 884: error = 0.6941548, gradient norm = 0.0000446
# [t-SNE] Iteration 885: error = 0.6941169, gradient norm = 0.0000434
# [t-SNE] Iteration 886: error = 0.6940791, gradient norm = 0.0000427
# [t-SNE] Iteration 887: error = 0.6940414, gradient norm = 0.0000431
# [t-SNE] Iteration 888: error = 0.6940038, gradient norm = 0.0000434
# [t-SNE] Iteration 889: error = 0.6939661, gradient norm = 0.0000426
# [t-SNE] Iteration 890: error = 0.6939284, gradient norm = 0.0000409
# [t-SNE] Iteration 891: error = 0.6938909, gradient norm = 0.0000408
# [t-SNE] Iteration 892: error = 0.6938534, gradient norm = 0.0000404
# [t-SNE] Iteration 893: error = 0.6938159, gradient norm = 0.0000392
# [t-SNE] Iteration 894: error = 0.6937785, gradient norm = 0.0000393
# [t-SNE] Iteration 895: error = 0.6937411, gradient norm = 0.0000393
# [t-SNE] Iteration 896: error = 0.6937036, gradient norm = 0.0000390
# [t-SNE] Iteration 897: error = 0.6936661, gradient norm = 0.0000394
# [t-SNE] Iteration 898: error = 0.6936286, gradient norm = 0.0000388
# [t-SNE] Iteration 899: error = 0.6935910, gradient norm = 0.0000387
# [t-SNE] Iteration 900: error = 0.6935535, gradient norm = 0.0000385
# [t-SNE] Iteration 901: error = 0.6935159, gradient norm = 0.0000387
# [t-SNE] Iteration 902: error = 0.6934783, gradient norm = 0.0000386
# [t-SNE] Iteration 903: error = 0.6934408, gradient norm = 0.0000386
# [t-SNE] Iteration 904: error = 0.6934033, gradient norm = 0.0000384
# [t-SNE] Iteration 905: error = 0.6933658, gradient norm = 0.0000397
# [t-SNE] Iteration 906: error = 0.6933283, gradient norm = 0.0000389
# [t-SNE] Iteration 907: error = 0.6932909, gradient norm = 0.0000388
# [t-SNE] Iteration 908: error = 0.6932535, gradient norm = 0.0000384
# [t-SNE] Iteration 909: error = 0.6932161, gradient norm = 0.0000375
# [t-SNE] Iteration 910: error = 0.6931789, gradient norm = 0.0000379
# [t-SNE] Iteration 911: error = 0.6931418, gradient norm = 0.0000385
# [t-SNE] Iteration 912: error = 0.6931046, gradient norm = 0.0000382
# [t-SNE] Iteration 913: error = 0.6930675, gradient norm = 0.0000384
# [t-SNE] Iteration 914: error = 0.6930304, gradient norm = 0.0000386
# [t-SNE] Iteration 915: error = 0.6929934, gradient norm = 0.0000383
# [t-SNE] Iteration 916: error = 0.6929564, gradient norm = 0.0000384
# [t-SNE] Iteration 917: error = 0.6929196, gradient norm = 0.0000378
# [t-SNE] Iteration 918: error = 0.6928829, gradient norm = 0.0000374
# [t-SNE] Iteration 919: error = 0.6928462, gradient norm = 0.0000376
# [t-SNE] Iteration 920: error = 0.6928097, gradient norm = 0.0000376
# [t-SNE] Iteration 921: error = 0.6927732, gradient norm = 0.0000374
# [t-SNE] Iteration 922: error = 0.6927367, gradient norm = 0.0000370
# [t-SNE] Iteration 923: error = 0.6927004, gradient norm = 0.0000369
# [t-SNE] Iteration 924: error = 0.6926641, gradient norm = 0.0000371
# [t-SNE] Iteration 925: error = 0.6926278, gradient norm = 0.0000366
# [t-SNE] Iteration 926: error = 0.6925916, gradient norm = 0.0000367
# [t-SNE] Iteration 927: error = 0.6925555, gradient norm = 0.0000373
# [t-SNE] Iteration 928: error = 0.6925195, gradient norm = 0.0000379
# [t-SNE] Iteration 929: error = 0.6924836, gradient norm = 0.0000394
# [t-SNE] Iteration 930: error = 0.6924478, gradient norm = 0.0000392
# [t-SNE] Iteration 931: error = 0.6924121, gradient norm = 0.0000387
# [t-SNE] Iteration 932: error = 0.6923766, gradient norm = 0.0000366
# [t-SNE] Iteration 933: error = 0.6923416, gradient norm = 0.0000367
# [t-SNE] Iteration 934: error = 0.6923067, gradient norm = 0.0000374
# [t-SNE] Iteration 935: error = 0.6922720, gradient norm = 0.0000357
# [t-SNE] Iteration 936: error = 0.6922374, gradient norm = 0.0000353
# [t-SNE] Iteration 937: error = 0.6922031, gradient norm = 0.0000353
# [t-SNE] Iteration 938: error = 0.6921688, gradient norm = 0.0000351
# [t-SNE] Iteration 939: error = 0.6921346, gradient norm = 0.0000354
# [t-SNE] Iteration 940: error = 0.6921005, gradient norm = 0.0000347
# [t-SNE] Iteration 941: error = 0.6920665, gradient norm = 0.0000346
# [t-SNE] Iteration 942: error = 0.6920325, gradient norm = 0.0000347
# [t-SNE] Iteration 943: error = 0.6919986, gradient norm = 0.0000350
# [t-SNE] Iteration 944: error = 0.6919648, gradient norm = 0.0000349
# [t-SNE] Iteration 945: error = 0.6919311, gradient norm = 0.0000346
# [t-SNE] Iteration 946: error = 0.6918974, gradient norm = 0.0000350
# [t-SNE] Iteration 947: error = 0.6918639, gradient norm = 0.0000353
# [t-SNE] Iteration 948: error = 0.6918305, gradient norm = 0.0000354
# [t-SNE] Iteration 949: error = 0.6917971, gradient norm = 0.0000351
# [t-SNE] Iteration 950: error = 0.6917639, gradient norm = 0.0000347
# [t-SNE] Iteration 951: error = 0.6917308, gradient norm = 0.0000361
# [t-SNE] Iteration 952: error = 0.6916980, gradient norm = 0.0000365
# [t-SNE] Iteration 953: error = 0.6916652, gradient norm = 0.0000354
# [t-SNE] Iteration 954: error = 0.6916326, gradient norm = 0.0000342
# [t-SNE] Iteration 955: error = 0.6916004, gradient norm = 0.0000350
# [t-SNE] Iteration 956: error = 0.6915682, gradient norm = 0.0000349
# [t-SNE] Iteration 957: error = 0.6915363, gradient norm = 0.0000343
# [t-SNE] Iteration 958: error = 0.6915045, gradient norm = 0.0000342
# [t-SNE] Iteration 959: error = 0.6914729, gradient norm = 0.0000333
# [t-SNE] Iteration 960: error = 0.6914415, gradient norm = 0.0000336
# [t-SNE] Iteration 961: error = 0.6914102, gradient norm = 0.0000335
# [t-SNE] Iteration 962: error = 0.6913790, gradient norm = 0.0000332
# [t-SNE] Iteration 963: error = 0.6913479, gradient norm = 0.0000328
# [t-SNE] Iteration 964: error = 0.6913169, gradient norm = 0.0000329
# [t-SNE] Iteration 965: error = 0.6912861, gradient norm = 0.0000325
# [t-SNE] Iteration 966: error = 0.6912553, gradient norm = 0.0000326
# [t-SNE] Iteration 967: error = 0.6912246, gradient norm = 0.0000324
# [t-SNE] Iteration 968: error = 0.6911941, gradient norm = 0.0000323
# [t-SNE] Iteration 969: error = 0.6911636, gradient norm = 0.0000322
# [t-SNE] Iteration 970: error = 0.6911332, gradient norm = 0.0000325
# [t-SNE] Iteration 971: error = 0.6911029, gradient norm = 0.0000328
# [t-SNE] Iteration 972: error = 0.6910728, gradient norm = 0.0000335
# [t-SNE] Iteration 973: error = 0.6910427, gradient norm = 0.0000347
# [t-SNE] Iteration 974: error = 0.6910127, gradient norm = 0.0000356
# [t-SNE] Iteration 975: error = 0.6909828, gradient norm = 0.0000338
# [t-SNE] Iteration 976: error = 0.6909532, gradient norm = 0.0000325
# [t-SNE] Iteration 977: error = 0.6909239, gradient norm = 0.0000329
# [t-SNE] Iteration 978: error = 0.6908948, gradient norm = 0.0000326
# [t-SNE] Iteration 979: error = 0.6908658, gradient norm = 0.0000323
# [t-SNE] Iteration 980: error = 0.6908370, gradient norm = 0.0000320
# [t-SNE] Iteration 981: error = 0.6908085, gradient norm = 0.0000320
# [t-SNE] Iteration 982: error = 0.6907801, gradient norm = 0.0000325
# [t-SNE] Iteration 983: error = 0.6907518, gradient norm = 0.0000330
# [t-SNE] Iteration 984: error = 0.6907236, gradient norm = 0.0000321
# [t-SNE] Iteration 985: error = 0.6906955, gradient norm = 0.0000319
# [t-SNE] Iteration 986: error = 0.6906675, gradient norm = 0.0000324
# [t-SNE] Iteration 987: error = 0.6906397, gradient norm = 0.0000318
# [t-SNE] Iteration 988: error = 0.6906120, gradient norm = 0.0000314
# [t-SNE] Iteration 989: error = 0.6905845, gradient norm = 0.0000311
# [t-SNE] Iteration 990: error = 0.6905570, gradient norm = 0.0000309
# [t-SNE] Iteration 991: error = 0.6905297, gradient norm = 0.0000309
# [t-SNE] Iteration 992: error = 0.6905025, gradient norm = 0.0000309
# [t-SNE] Iteration 993: error = 0.6904754, gradient norm = 0.0000304
# [t-SNE] Iteration 994: error = 0.6904483, gradient norm = 0.0000303
# [t-SNE] Iteration 995: error = 0.6904213, gradient norm = 0.0000302
# [t-SNE] Iteration 996: error = 0.6903944, gradient norm = 0.0000300
# [t-SNE] Iteration 997: error = 0.6903676, gradient norm = 0.0000299
# [t-SNE] Iteration 998: error = 0.6903408, gradient norm = 0.0000303
# [t-SNE] Iteration 999: error = 0.6903141, gradient norm = 0.0000299
# [t-SNE] Iteration 1000: error = 0.6902874, gradient norm = 0.0000300

# %%
X_embedded
# Out:
# array([[  4.2258625,  65.40724  ],
#        [  3.2298727,  10.028559 ],
#        [-17.108297 ,  -5.55982  ],
#        ...,
#        [ -5.9372134,  -7.1946416],
#        [ -1.5275459, -42.90323  ],
#        [ -8.19329  , -13.172117 ]], dtype=float32)

# %%
y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
sns.scatterplot(data = X, x = X_embedded[:,0], y = X_embedded[:,1], hue=y, legend='full', palette=palette)
# Out:
# <AxesSubplot: >

# %%
tsne = TSNE()
X_embedded = tsne.fit_transform(X)

sns.scatterplot(data = X, x=X_embedded[:,0], y = X_embedded[:,1], hue=y, legend='full', palette=palette)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# <AxesSubplot: >
